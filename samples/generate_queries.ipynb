# %%
import os
import json
import subprocess

# %%
datasetlist = ['ZHiggs0L1ToGG',
'ZHiggs0L1ZgToGG',
'ZHiggs0L1Zgf05ph0ToGG',
'ZHiggs0L1f05ph0ToGG',
'ZHiggs0MToGG',
'ZHiggs0PHToGG',
'ZHiggs0PHf05ph0ToGG',
'ZHiggs0PMToGG',
'ZHiggs0Mf05ph0ToGG',
'WHiggs0L1ToGG',
'WHiggs0L1f05ph0ToGG',
'WHiggs0MToGG',
'WHiggs0Mf05ph0ToGG',
'WHiggs0PHToGG',
'WHiggs0PHf05ph0ToGG',
'WHiggs0PMToGG',
'GluGluHToGG_M125',
'VBFHToGG_M125',
'VHToGG_M125',
'ttHJetToGG_M125',
'DYJetsToLL_M-50',
'DiPhotonJetsBox_M40',
'DiPhotonJetsBox_MGG-80toInf',
'GJet_Pt-20to40',
'GJet_Pt-40toInf',
'TTGJets_TuneCP5',
'TTJets_TuneCP5',
'WGToLNuG_01J',
'WW_TuneCP5',
'WZ_TuneCP5',
'ZGToLLG_01J',
'ZZ_TuneCP5',
'TGJets_TuneCP5',
'TTGG_0Jets']

# %%
era = {
    '2018': 'RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16',
    '2017': 'RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9',
    '2016_preVFP': 'RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11',
    '2016_postVFP': 'RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17'
}

# %%
for yr in era:
    for dset in datasetlist:
        print('dasgoclient --query "dataset dataset=/{dset}*/*{cond}*/MINIAODSIM" -json > {dset}_{yr}.json'.format(dset=dset,yr=yr,cond=era[yr]))
# Out:
# dasgoclient --query "dataset dataset=/TGJets_TuneCP5*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/MINIAODSIM" -json > TGJets_TuneCP5_2018.json
# dasgoclient --query "dataset dataset=/TTGG_0Jets*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/MINIAODSIM" -json > TTGG_0Jets_2018.json
# dasgoclient --query "dataset dataset=/TGJets_TuneCP5*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/MINIAODSIM" -json > TGJets_TuneCP5_2017.json
# dasgoclient --query "dataset dataset=/TTGG_0Jets*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/MINIAODSIM" -json > TTGG_0Jets_2017.json
# dasgoclient --query "dataset dataset=/TGJets_TuneCP5*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/MINIAODSIM" -json > TGJets_TuneCP5_2016_preVFP.json
# dasgoclient --query "dataset dataset=/TTGG_0Jets*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/MINIAODSIM" -json > TTGG_0Jets_2016_preVFP.json
# dasgoclient --query "dataset dataset=/TGJets_TuneCP5*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/MINIAODSIM" -json > TGJets_TuneCP5_2016_postVFP.json
# dasgoclient --query "dataset dataset=/TTGG_0Jets*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/MINIAODSIM" -json > TTGG_0Jets_2016_postVFP.json

# %% [markdown]
# ### GJet samples have a different condition tag
# /GJet_Pt-40toInf_DoubleEMEnriched_MGG-80toInf_TuneCP5_13TeV_Pythia8/RunIISummer20UL18MiniAOD-106X_upgrade2018_realistic_v11_L1v1-v3/MINIAODSIM
#
# Using alt_tag for checking the datasets in das.

# %%
alt_era = {
    '2016_postVFP': 'RunIISummer20UL16MiniAOD-106X_mcRun2_asymptotic_v13-v3',
    '2016_preVFP': 'RunIISummer20UL16MiniAODAPV-106X_mcRun2_asymptotic_preVFP_v8-v3',
    '2017': 'RunIISummer20UL17MiniAOD-106X_mc2017_realistic_v6-v3',
    '2018': 'RunIISummer20UL18MiniAOD-106X_upgrade2018_realistic_v11_L1v1-v3'
}

# %%
for yr in alt_era:
    for dset in datasetlist:
        if 'GJet_Pt-40toInf' not in dset: continue
        print('dasgoclient --query "dataset dataset=/{dset}*/*{cond}*/MINIAODSIM" -json > {dset}_{yr}.json'.format(dset=dset,yr=yr,cond=alt_era[yr]))
# Out:
# dasgoclient --query "dataset dataset=/GJet_Pt-40toInf*/*RunIISummer20UL16MiniAOD-106X_mcRun2_asymptotic_v13-v3*/MINIAODSIM" -json > GJet_Pt-40toInf_2016_postVFP.json
# dasgoclient --query "dataset dataset=/GJet_Pt-40toInf*/*RunIISummer20UL16MiniAODAPV-106X_mcRun2_asymptotic_preVFP_v8-v3*/MINIAODSIM" -json > GJet_Pt-40toInf_2016_preVFP.json
# dasgoclient --query "dataset dataset=/GJet_Pt-40toInf*/*RunIISummer20UL17MiniAOD-106X_mc2017_realistic_v6-v3*/MINIAODSIM" -json > GJet_Pt-40toInf_2017.json
# dasgoclient --query "dataset dataset=/GJet_Pt-40toInf*/*RunIISummer20UL18MiniAOD-106X_upgrade2018_realistic_v11_L1v1-v3*/MINIAODSIM" -json > GJet_Pt-40toInf_2018.json

# %% [markdown]
# ### check if microaods are present
# dasgoclient --query "dataset dataset=/WminusH_HToGG*/*/USER* instance=prod/phys03"

# %%
for yr in era:
    for dset in datasetlist:
        if 'GJet_Pt-40toInf' not in dset:
            print('dasgoclient --query "dataset dataset=/{dset}*/*{cond}*/USER instance=prod/phys03" -json > microaod/microaod_{dset}_{yr}.json'.format(dset=dset,yr=yr,cond=era[yr]))
        else:
            print('dasgoclient --query "dataset dataset=/{dset}*/*{cond}*/USER instance=prod/phys03" -json > microaod/microaod_{dset}_{yr}.json'.format(dset=dset,yr=yr,cond=alt_era[yr]))
# Out:
# dasgoclient --query "dataset dataset=/ZHiggs0L1ToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1ToGG_2018.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1ZgToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1ZgToGG_2018.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1Zgf05ph0ToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1Zgf05ph0ToGG_2018.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1f05ph0ToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1f05ph0ToGG_2018.json
# dasgoclient --query "dataset dataset=/ZHiggs0MToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0MToGG_2018.json
# dasgoclient --query "dataset dataset=/ZHiggs0PHToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0PHToGG_2018.json
# dasgoclient --query "dataset dataset=/ZHiggs0PHf05ph0ToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0PHf05ph0ToGG_2018.json
# dasgoclient --query "dataset dataset=/ZHiggs0PMToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0PMToGG_2018.json
# dasgoclient --query "dataset dataset=/ZHiggs0Mf05ph0ToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0Mf05ph0ToGG_2018.json
# dasgoclient --query "dataset dataset=/WHiggs0L1ToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0L1ToGG_2018.json
# dasgoclient --query "dataset dataset=/WHiggs0L1f05ph0ToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0L1f05ph0ToGG_2018.json
# dasgoclient --query "dataset dataset=/WHiggs0MToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0MToGG_2018.json
# dasgoclient --query "dataset dataset=/WHiggs0Mf05ph0ToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0Mf05ph0ToGG_2018.json
# dasgoclient --query "dataset dataset=/WHiggs0PHToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0PHToGG_2018.json
# dasgoclient --query "dataset dataset=/WHiggs0PHf05ph0ToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0PHf05ph0ToGG_2018.json
# dasgoclient --query "dataset dataset=/WHiggs0PMToGG*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0PMToGG_2018.json
# dasgoclient --query "dataset dataset=/GluGluHToGG_M125*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_GluGluHToGG_M125_2018.json
# dasgoclient --query "dataset dataset=/VBFHToGG_M125*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_VBFHToGG_M125_2018.json
# dasgoclient --query "dataset dataset=/VHToGG_M125*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_VHToGG_M125_2018.json
# dasgoclient --query "dataset dataset=/ttHJetToGG_M125*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_ttHJetToGG_M125_2018.json
# dasgoclient --query "dataset dataset=/DYJetsToLL_M-50*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_DYJetsToLL_M-50_2018.json
# dasgoclient --query "dataset dataset=/DiPhotonJetsBox_M40*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_DiPhotonJetsBox_M40_2018.json
# dasgoclient --query "dataset dataset=/DiPhotonJetsBox_MGG-80toInf*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_DiPhotonJetsBox_MGG-80toInf_2018.json
# dasgoclient --query "dataset dataset=/GJet_Pt-20to40*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_GJet_Pt-20to40_2018.json
# dasgoclient --query "dataset dataset=/GJet_Pt-40toInf*/*RunIISummer20UL18MiniAOD-106X_upgrade2018_realistic_v11_L1v1-v3*/USER instance=prod/phys03" -json > microaod/microaod_GJet_Pt-40toInf_2018.json
# dasgoclient --query "dataset dataset=/TTGJets_TuneCP5*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_TTGJets_TuneCP5_2018.json
# dasgoclient --query "dataset dataset=/TTJets_TuneCP5*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_TTJets_TuneCP5_2018.json
# dasgoclient --query "dataset dataset=/WGToLNuG_01J*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_WGToLNuG_01J_2018.json
# dasgoclient --query "dataset dataset=/WW_TuneCP5*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_WW_TuneCP5_2018.json
# dasgoclient --query "dataset dataset=/WZ_TuneCP5*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_WZ_TuneCP5_2018.json
# dasgoclient --query "dataset dataset=/ZGToLLG_01J*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_ZGToLLG_01J_2018.json
# dasgoclient --query "dataset dataset=/ZZ_TuneCP5*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_ZZ_TuneCP5_2018.json
# dasgoclient --query "dataset dataset=/TGJets_TuneCP5*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_TGJets_TuneCP5_2018.json
# dasgoclient --query "dataset dataset=/TTGG_0Jets*/*RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16*/USER instance=prod/phys03" -json > microaod/microaod_TTGG_0Jets_2018.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1ToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1ToGG_2017.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1ZgToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1ZgToGG_2017.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1Zgf05ph0ToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1Zgf05ph0ToGG_2017.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1f05ph0ToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1f05ph0ToGG_2017.json
# dasgoclient --query "dataset dataset=/ZHiggs0MToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0MToGG_2017.json
# dasgoclient --query "dataset dataset=/ZHiggs0PHToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0PHToGG_2017.json
# dasgoclient --query "dataset dataset=/ZHiggs0PHf05ph0ToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0PHf05ph0ToGG_2017.json
# dasgoclient --query "dataset dataset=/ZHiggs0PMToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0PMToGG_2017.json
# dasgoclient --query "dataset dataset=/ZHiggs0Mf05ph0ToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0Mf05ph0ToGG_2017.json
# dasgoclient --query "dataset dataset=/WHiggs0L1ToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0L1ToGG_2017.json
# dasgoclient --query "dataset dataset=/WHiggs0L1f05ph0ToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0L1f05ph0ToGG_2017.json
# dasgoclient --query "dataset dataset=/WHiggs0MToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0MToGG_2017.json
# dasgoclient --query "dataset dataset=/WHiggs0Mf05ph0ToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0Mf05ph0ToGG_2017.json
# dasgoclient --query "dataset dataset=/WHiggs0PHToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0PHToGG_2017.json
# dasgoclient --query "dataset dataset=/WHiggs0PHf05ph0ToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0PHf05ph0ToGG_2017.json
# dasgoclient --query "dataset dataset=/WHiggs0PMToGG*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0PMToGG_2017.json
# dasgoclient --query "dataset dataset=/GluGluHToGG_M125*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_GluGluHToGG_M125_2017.json
# dasgoclient --query "dataset dataset=/VBFHToGG_M125*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_VBFHToGG_M125_2017.json
# dasgoclient --query "dataset dataset=/VHToGG_M125*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_VHToGG_M125_2017.json
# dasgoclient --query "dataset dataset=/ttHJetToGG_M125*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_ttHJetToGG_M125_2017.json
# dasgoclient --query "dataset dataset=/DYJetsToLL_M-50*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_DYJetsToLL_M-50_2017.json
# dasgoclient --query "dataset dataset=/DiPhotonJetsBox_M40*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_DiPhotonJetsBox_M40_2017.json
# dasgoclient --query "dataset dataset=/DiPhotonJetsBox_MGG-80toInf*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_DiPhotonJetsBox_MGG-80toInf_2017.json
# dasgoclient --query "dataset dataset=/GJet_Pt-20to40*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_GJet_Pt-20to40_2017.json
# dasgoclient --query "dataset dataset=/GJet_Pt-40toInf*/*RunIISummer20UL17MiniAOD-106X_mc2017_realistic_v6-v3*/USER instance=prod/phys03" -json > microaod/microaod_GJet_Pt-40toInf_2017.json
# dasgoclient --query "dataset dataset=/TTGJets_TuneCP5*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_TTGJets_TuneCP5_2017.json
# dasgoclient --query "dataset dataset=/TTJets_TuneCP5*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_TTJets_TuneCP5_2017.json
# dasgoclient --query "dataset dataset=/WGToLNuG_01J*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_WGToLNuG_01J_2017.json
# dasgoclient --query "dataset dataset=/WW_TuneCP5*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_WW_TuneCP5_2017.json
# dasgoclient --query "dataset dataset=/WZ_TuneCP5*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_WZ_TuneCP5_2017.json
# dasgoclient --query "dataset dataset=/ZGToLLG_01J*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_ZGToLLG_01J_2017.json
# dasgoclient --query "dataset dataset=/ZZ_TuneCP5*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_ZZ_TuneCP5_2017.json
# dasgoclient --query "dataset dataset=/TGJets_TuneCP5*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_TGJets_TuneCP5_2017.json
# dasgoclient --query "dataset dataset=/TTGG_0Jets*/*RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9*/USER instance=prod/phys03" -json > microaod/microaod_TTGG_0Jets_2017.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1ToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1ToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1ZgToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1ZgToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1Zgf05ph0ToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1Zgf05ph0ToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1f05ph0ToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1f05ph0ToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0MToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0MToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0PHToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0PHToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0PHf05ph0ToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0PHf05ph0ToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0PMToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0PMToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0Mf05ph0ToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0Mf05ph0ToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0L1ToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0L1ToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0L1f05ph0ToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0L1f05ph0ToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0MToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0MToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0Mf05ph0ToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0Mf05ph0ToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0PHToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0PHToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0PHf05ph0ToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0PHf05ph0ToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0PMToGG*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0PMToGG_2016_preVFP.json
# dasgoclient --query "dataset dataset=/GluGluHToGG_M125*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_GluGluHToGG_M125_2016_preVFP.json
# dasgoclient --query "dataset dataset=/VBFHToGG_M125*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_VBFHToGG_M125_2016_preVFP.json
# dasgoclient --query "dataset dataset=/VHToGG_M125*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_VHToGG_M125_2016_preVFP.json
# dasgoclient --query "dataset dataset=/ttHJetToGG_M125*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_ttHJetToGG_M125_2016_preVFP.json
# dasgoclient --query "dataset dataset=/DYJetsToLL_M-50*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_DYJetsToLL_M-50_2016_preVFP.json
# dasgoclient --query "dataset dataset=/DiPhotonJetsBox_M40*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_DiPhotonJetsBox_M40_2016_preVFP.json
# dasgoclient --query "dataset dataset=/DiPhotonJetsBox_MGG-80toInf*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_DiPhotonJetsBox_MGG-80toInf_2016_preVFP.json
# dasgoclient --query "dataset dataset=/GJet_Pt-20to40*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_GJet_Pt-20to40_2016_preVFP.json
# dasgoclient --query "dataset dataset=/GJet_Pt-40toInf*/*RunIISummer20UL16MiniAODAPV-106X_mcRun2_asymptotic_preVFP_v8-v3*/USER instance=prod/phys03" -json > microaod/microaod_GJet_Pt-40toInf_2016_preVFP.json
# dasgoclient --query "dataset dataset=/TTGJets_TuneCP5*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_TTGJets_TuneCP5_2016_preVFP.json
# dasgoclient --query "dataset dataset=/TTJets_TuneCP5*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_TTJets_TuneCP5_2016_preVFP.json
# dasgoclient --query "dataset dataset=/WGToLNuG_01J*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_WGToLNuG_01J_2016_preVFP.json
# dasgoclient --query "dataset dataset=/WW_TuneCP5*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_WW_TuneCP5_2016_preVFP.json
# dasgoclient --query "dataset dataset=/WZ_TuneCP5*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_WZ_TuneCP5_2016_preVFP.json
# dasgoclient --query "dataset dataset=/ZGToLLG_01J*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_ZGToLLG_01J_2016_preVFP.json
# dasgoclient --query "dataset dataset=/ZZ_TuneCP5*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_ZZ_TuneCP5_2016_preVFP.json
# dasgoclient --query "dataset dataset=/TGJets_TuneCP5*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_TGJets_TuneCP5_2016_preVFP.json
# dasgoclient --query "dataset dataset=/TTGG_0Jets*/*RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11*/USER instance=prod/phys03" -json > microaod/microaod_TTGG_0Jets_2016_preVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1ToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1ToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1ZgToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1ZgToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1Zgf05ph0ToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1Zgf05ph0ToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0L1f05ph0ToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0L1f05ph0ToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0MToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0MToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0PHToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0PHToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0PHf05ph0ToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0PHf05ph0ToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0PMToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0PMToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/ZHiggs0Mf05ph0ToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_ZHiggs0Mf05ph0ToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0L1ToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0L1ToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0L1f05ph0ToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0L1f05ph0ToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0MToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0MToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0Mf05ph0ToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0Mf05ph0ToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0PHToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0PHToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0PHf05ph0ToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0PHf05ph0ToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/WHiggs0PMToGG*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_WHiggs0PMToGG_2016_postVFP.json
# dasgoclient --query "dataset dataset=/GluGluHToGG_M125*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_GluGluHToGG_M125_2016_postVFP.json
# dasgoclient --query "dataset dataset=/VBFHToGG_M125*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_VBFHToGG_M125_2016_postVFP.json
# dasgoclient --query "dataset dataset=/VHToGG_M125*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_VHToGG_M125_2016_postVFP.json
# dasgoclient --query "dataset dataset=/ttHJetToGG_M125*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_ttHJetToGG_M125_2016_postVFP.json
# dasgoclient --query "dataset dataset=/DYJetsToLL_M-50*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_DYJetsToLL_M-50_2016_postVFP.json
# dasgoclient --query "dataset dataset=/DiPhotonJetsBox_M40*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_DiPhotonJetsBox_M40_2016_postVFP.json
# dasgoclient --query "dataset dataset=/DiPhotonJetsBox_MGG-80toInf*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_DiPhotonJetsBox_MGG-80toInf_2016_postVFP.json
# dasgoclient --query "dataset dataset=/GJet_Pt-20to40*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_GJet_Pt-20to40_2016_postVFP.json
# dasgoclient --query "dataset dataset=/GJet_Pt-40toInf*/*RunIISummer20UL16MiniAOD-106X_mcRun2_asymptotic_v13-v3*/USER instance=prod/phys03" -json > microaod/microaod_GJet_Pt-40toInf_2016_postVFP.json
# dasgoclient --query "dataset dataset=/TTGJets_TuneCP5*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_TTGJets_TuneCP5_2016_postVFP.json
# dasgoclient --query "dataset dataset=/TTJets_TuneCP5*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_TTJets_TuneCP5_2016_postVFP.json
# dasgoclient --query "dataset dataset=/WGToLNuG_01J*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_WGToLNuG_01J_2016_postVFP.json
# dasgoclient --query "dataset dataset=/WW_TuneCP5*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_WW_TuneCP5_2016_postVFP.json
# dasgoclient --query "dataset dataset=/WZ_TuneCP5*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_WZ_TuneCP5_2016_postVFP.json
# dasgoclient --query "dataset dataset=/ZGToLLG_01J*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_ZGToLLG_01J_2016_postVFP.json
# dasgoclient --query "dataset dataset=/ZZ_TuneCP5*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_ZZ_TuneCP5_2016_postVFP.json
# dasgoclient --query "dataset dataset=/TGJets_TuneCP5*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_TGJets_TuneCP5_2016_postVFP.json
# dasgoclient --query "dataset dataset=/TTGG_0Jets*/*RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17*/USER instance=prod/phys03" -json > microaod/microaod_TTGG_0Jets_2016_postVFP.json

# %%
db = {}
for dset in datasetlist:
    db[dset] = {}
    for yr in era:
        
        jsonfile = 'microaod/microaod_{dset}_{year}.json'.format(dset=dset, year=yr)
        
        with open(jsonfile, 'r') as f0:
            das_ = json.load(f0)
        db[dset][yr] = {
            'ndatasets': len(das_)
            'name': [],
            'modification_time': [],
            'location': []
        }
        
        for i in range(len(das_)):
            mdtime_ = das_[i]['dataset'][0]['modification_time']
            name_ = das_[i]['dataset'][0]['name']

            # get location
            q_ = "file dataset={name_} instance=prod/phys03".format(name_=name_)
            p = subprocess.Popen(["dasgoclient", "--query", q_], stdout=subprocess.PIPE)
            stdout, stderr = p.communicate()
            files = [ f for f in stdout.decode('utf-8').split('\n') if f!='' ]
            loc_ = ''
            if len(files)>0: loc_ = '/eos/cms'+'/'.join(files[0].split('/')[:-1])
            
            db[dset][yr]['name'].append(name_)
            db[dset][yr]['modification_time'].append(mdtime_)
            db[dset][yr]['location'].append(loc_)
